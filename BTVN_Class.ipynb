# %%
# Xây dựng lớp hình tròn có bán kính r. 
# Phương thức: Gồm kiểm tra sự tồn tại hình tròn, tính chu vi và diện tích
import math

class Hinhtron:
    
    # Constructor
    def __init__(self, r):
        self.r = r
        
    def validate(self):
        if self.r > 0:
            return True
        else:
            return False
    
    def area(self):
        if self.validate() is True:
            return math.pow(self.r,2) * math.pi
    
    def lenght(self):
        if self.validate() is True:
            return self.r * 2 * math.pi

#r = float(input('Nhập bán kính: '))
#ht = Hinhtron(r)
#chuvi = ht.lenght()
#dientich = ht.area()
#print('Chu vi =', chuvi)
#print('Diện tích =', dientich)

# %%
import math

class PTB2:
    
    # Constructor
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
    
    def nghiem(self):
        if self.a == 0:
            if self.b == 0:
                if self.c == 0:
                    x = 'vô số nghiệm'
                    x1 = x2 = None
                else:
                    x = 'vô nghiệm'
                    x1 = x2 = None
            else:
                x = 'nghiệm kép'
                x1 = x2 = -self.c/self.b
        else:
            delta = self.b*self.b - 4*self.a*self.c

            if delta < 0:
                x = 'vô nghiệm'
                x1 = x2 = None
            elif delta == 0:
                x = 'nghiệm kép'
                x1 = x2 = -self.b/(2*self.a)
            elif delta > 0:
                x = 'hai nghiệm'
                x1 = (-self.b + delta**0.5)/(2*self.a)
                x2 = (-self.b - delta**0.5)/(2*self.a)
        return x, x1, x2
    
    def phuongtrinh(self):
        if self.a != 0 and self.b != 0 and self.c != 0:
            if self.a == 1 and self.a != -1 and self.b != 1 and self.b != -1:
                self.a = ''
            elif self.a == -1 and self.a != 1 and self.b != 1 and self.b != -1:
                self.a = '-'
            elif self.b == 1 and self.a != 1 and self.a != -1 and self.b != -1: 
                self.b = ''
            elif self.b == -1 and self.a != 1 and self.a != -1 and self.b != 1: 
                self.b = '-' 
            elif self.a == 1 and self.b == 1 and self.a != -1 and self.b != -1:
                self.a = ''
                self.b = ''
            elif self.a == -1 and self.b == -1 and self.a != 1 and self.b != 1:
                self.a = '-'
                self.b = '-'
            elif self.a == 1 and self.b == -1 and self.a != -1 and self.b != 1:
                self.a = ''
                self.b = '-'
            elif self.a == -1 and self.b == 1 and self.a != 1 and self.b != -1:
                self.a = '-'
                self.b = ''
            print('Phương trình bậc 2: {a}x^2 + {b}x + {c} = 0'.format(a=self.a, b=self.b, c=self.c))


        if self.a != 0 and self.b != 0 and self.c == 0:
            if self.a == 1 and self.a != -1 and self.b != 1 and self.b != -1:
                self.a = ''
            elif self.a == -1 and self.a != 1 and self.b != 1 and self.b != -1:
                self.a = '-'
            elif self.b == 1 and self.a != 1 and self.a != -1 and self.b != -1: 
                self.b = ''
            elif self.b == -1 and self.a != 1 and self.a != -1 and self.b != 1: 
                self.b = '-' 
            elif self.a == 1 and self.b == 1 and self.a != -1 and self.b != -1:
                self.a = ''
                self.b = ''
            elif self.a == -1 and self.b == -1 and self.a != 1 and self.b != 1:
                self.a = '-'
                self.b = '-'
            elif self.a == 1 and self.b == -1 and self.a != -1 and self.b != 1:
                self.a = ''
                self.b = '-'
            elif self.a == -1 and self.b == 1 and self.a != 1 and self.b != -1:
                self.a = '-'
                self.b = ''
            print('Phương trình bậc 2: {a}x^2 + {b}x = 0'.format(a=self.a, b=self.b))
            
        if self.a == 0 and self.b != 0 and self.c != 0:
            if self.b == 1 and self.b != -1: 
                self.b = ''
            elif self.b == -1 and self.b != 1: 
                self.b = '-' 
            print('Phương trình bậc 1: {b}x + {c} = 0'.format(b=self.b, c=self.c))

        if self.a != 0 and self.b == 0 and self.c != 0:
            if self.a == 1 and self.a != -1:
                self.a = ''
            elif self.a == -1 and self.a != 1:
                self.a = '-'
            print('Phương trình bậc 2: {a}x^2 + {c} = 0'.format(a=self.a, c=self.c))

        if self.a == 0 and self.b != 0 and self.c == 0:
            if self.b == 1 or self.b == -1:
                self.b = ''
            print('Phương trình bậc 1: {b}x = 0'.format(b=self.b))

        if self.a != 0 and self.b == 0 and self.c == 0:
            if self.a == 1 or self.a == -1:
                self.a = ''
            print('Phương trình bậc 2: {a}x^2 = 0'.format(a=self.a))

        if self.a == 0 and self.b == 0:
            print('Phương trình: {c} = 0'.format(c=self.c))
            
            
            
a = float(input('Nhập hệ số 1: '))
b = float(input('Nhập hệ số 2: '))
c = float(input('Nhập hệ số 3: '))
ptb2c = PTB2(a,b,c)
ptb2s = PTB2(a,b,c)
phuongtrinh = ptb2c.phuongtrinh()
nghiem = ptb2s.nghiem()
print('Nghiệm =', nghiem)
# Out:
# Nhập hệ số 1: 2
# Nhập hệ số 2: -10
# Nhập hệ số 3: 3
# Phương trình bậc 2: 2.0x^2 + -10.0x + 3.0 = 0
# Nghiệm = ('hai nghiệm', 4.6794494717703365, 0.320550528229663)
